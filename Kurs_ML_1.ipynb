# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcinSlusarczyk/ML-bootcamp/blob/main/Kurs_ML_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.preprocessing import StandardScaler, LabelEncoder
sklearn.__version__
# Out:
# '1.0.2'

# %%
data = {
    'size': ['XL', 'L', 'M', 'L', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red'],
    'gender': ['female', 'male', 'male', 'female', 'female'],
    'price': [199.0, 89.0, 99.0, 129.0, 79.0],
    'weight': [500, 450, 300, 380, 410],
    'bought': ['yes', 'no', 'yes', 'no', 'yes']
}

# %%
#wrzucamy do data frame
df_raw = pd.DataFrame(data=data)
df_raw
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0     500    yes
# 1    L  green    male   89.0     450     no
# 2    M   blue    male   99.0     300    yes
# 3    L  green  female  129.0     380     no
# 4    M    red  female   79.0     410    yes

# %%
#robimy kopie danych surowych
df = df_raw.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   size    5 non-null      object
#  1   color   5 non-null      object
#  2   gender  5 non-null      object
#  3   price   5 non-null      float64
#  4   weight  5 non-null      int64
#  5   bought  5 non-null      object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 368.0+ bytes

# %%
#mapujemy wartości yes/no na 1 i 0
le = LabelEncoder()
df['bought'] = le.fit_transform(df['bought'])

#liczymy odchylenie standardowe aby zniwelować rozrzut wartości
scaler = StandardScaler()
df[['weight', 'price']] = scaler.fit_transform(df[['weight', 'price']])

# dekodujemy wartości tekstowe na liczbowe
df = pd.get_dummies(data=df, drop_first=True)

df
# Out:
#       price    weight  bought  size_M  size_XL  color_green  color_red  \
# 0  1.845062  1.366002       1       0        1            0          1
# 1 -0.691898  0.623610       0       0        0            1          0
# 2 -0.461266 -1.603567       1       1        0            0          0
# 3  0.230633 -0.415740       0       0        0            1          0
# 4 -0.922531  0.029696       1       1        0            0          1
#
#    gender_male
# 0            0
# 1            1
# 2            1
# 3            0
# 4            0
